# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07',periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2020-11-12', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07  0.552699
# 2019-06-08 -1.312677
# 2019-06-09 -2.656377
# 2019-06-10  0.135934
# 2019-06-11 -0.406797

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  0.552699
# 2019-06-08 -0.759977
# 2019-06-09 -3.416355
# 2019-06-10 -3.280421
# 2019-06-11 -3.687218

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2020-11-12   -0.301868
# 2020-11-13   -1.799747
# 2020-11-14    0.293464
# 2020-11-15   -0.384598
# 2020-11-16   -0.899354
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))

# %%
plt.plot(ts)

# %%
df.plot()

# %% [markdown]
# # Dataset iris

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title = 'Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %% [markdown]
# # Dataset titanic

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a','b','c','d'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.063264 -0.160557 -0.296460 -2.533763
# 1  1.140906  1.673691  0.048601  1.576516
# 2  1.363140  2.332049 -0.974755  0.942122
# 3  0.234233  0.912666 -0.872646  1.352867
# 4  1.688607 -0.151448 -0.036137 -0.208979
# 5  0.788595  1.181077 -0.669751  0.461650
# 6 -0.353058  0.340353  0.362166  1.099487
# 7 -0.725666  1.017767 -1.177481  1.190917
# 8 -0.036885 -0.421518 -0.079024 -0.327390
# 9 -0.971569 -0.372272  0.450710 -1.639612

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins =50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E7F5D9048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E7F603348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E7F63BAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E7F675508>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers':'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y ='petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length', color = 'g');

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c ='sepal_width', s = 150)

# %%
df.plot.scatter(x = 'sepal_length', y ='petal_length', s = 200, color='r')

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
df.plot.hexbin(x = 'petal_length', y = 'sepal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
df1 = df.iloc[3]
df1
# Out:
# sepal_length    4.6
# sepal_width     3.1
# petal_length    1.5
# petal_width     0.2
# Name: 3, dtype: float64

# %%
#plot in pie
df1.plot.pie(figsize = (5,5))

# %%
#plot in histogram
df1.plot.hist(figsize = (5,5))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20,20), fontsize = 26)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E028E67C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E02AA1788>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E02AC1BC8>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20,20), fontsize = 26, autopct = '%d')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E02E747C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E02E9F508>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E0307C948>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20,20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E034843C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E0366BAC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E0368E0C8>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c','d','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize=(8,8), diagonal='kde', color = 'g')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis =1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True)

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
#Plotting all the features seperatly
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E088FB2C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E08B782C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E08B92148>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019E08BC8A48>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
